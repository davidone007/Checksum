# %% [markdown]
# #Single

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.038336930000000005, 0.4038590399999997, 2.9211799799999993, 31.730872090000005]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada (M: 1113 y blockSize: 2)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  31.747695166137543 x + ( -0.03721709098231869 )

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.04204997, 0.23265097, 2.3127811100000004, 23.224456030000002]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada (M: 11113 y blockSize: 5)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  23.211045513639103 x + ( 0.01133911382731191 )

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.03236996999999999, 0.25886109, 1.9728609699999995, 18.684122]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada (M: 1111113 y blockSize: 8)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  18.61821032974821 x + ( 0.07003468573662859 )

# %% [markdown]
# # Dual

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.06634502999999994, 0.39292400999999977, 3.5430899200000017, 33.256493070000005]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada(M: 1113 y blockSize: 2)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  33.1536015428706 x + ( 0.11375973931483843 )

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.05902093999999998, 0.5259349200000003, 2.5389198600000005, 23.947535930000004]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada(M: 11113 y blockSize: 5)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  23.779538133600592 x + ( 0.16843659197249788 )

# %%
tamanos_entrada = [100, 10000, 100000, 1000000]

# Tiempos de ejecución medidos para cada tamaño de entrada
tiempos_ejecucion = [0.06679604999999998, 0.43726403999999974, 2.2550250199999997, 21.811188980000008]

tamanos_entrada_scaled = [x / 1e6 for x in tamanos_entrada]
m, b = np.polyfit(tamanos_entrada_scaled, tiempos_ejecucion, 1)
print("y = ", m, "x + (", b,")")


plt.figure(figsize=(8, 5))
plt.plot(tamanos_entrada, tiempos_ejecucion, marker='o', linestyle='-', color='b')

# Configuración del gráfico
plt.title('Tiempo de Ejecución vs Tamaño de Entrada(M: 1111113 y blockSize: 8)')
plt.xlabel('Tamaño de Entrada')
plt.ylabel('Tiempo de Ejecución (milisegundos)')
plt.grid(True)

# Mostrar la gráfica
plt.show()
# Out:
# y =  21.683450847949203 x + ( 0.12486882592289882 )
